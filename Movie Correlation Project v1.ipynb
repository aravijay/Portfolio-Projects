# %%
# import libs

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure
import sklearn.metrics as skm

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# read in the data using pandas

df = pd.read_csv('D:\Downloads\movies.csv')

# %%
# looking at data now

df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Look for missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print(f"{col} - {round(pct_missing*100)}%")
# Out:
# name - 0%
# rating - 1%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 28%
# gross - 2%
# company - 0%
# runtime - 0%

# %%
print(df.dtypes)
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Are there any Outliers?

df.boxplot(column=['gross'])
# Out:
# <AxesSubplot:>

# %%
df['budget'] = df['budget'].astype('Int64')

# %%
df['gross'] = df['gross'].astype('Int64')

# %%
print(df.released[1])
# Out:
# July 2, 1980 (United States)

# %%
df.released[1].split(', ')
# Out:
# ['July 2', '1980 (United States)']

# %%
year = df.released[1].split(', ')[1]
print(year)
# Out:
# 1980 (United States)

# %%
type(df.released[1].split(', ')[1])
# Out:
# str

# %%
np.int64(df.released[1].split(', ')[1][:4])
# Out:
# 1980

# %%
df['yearcorrect'] = df['released'].astype('str').str.split(',').str[1][:4].str.strip()

# %%
df['yearcorrect'] = df['released'].astype('str').str.split(',').str[1]

# %%
df['yearcorrect'] = df['yearcorrect'].str[:5]

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df['yearcorrect'] = df['released'].astype('str').str.split(',').str[1]

# %%
df['yearcorrect'] = df['yearcorrect'].str.strip()

# %%
df['yearcorrect'] = df['yearcorrect'].str[:5]

# %%
df['yearcorrect'] = pd.to_numeric(df['yearcorrect'], errors='coerce').convert_dtypes()

# %%
df.dtypes
# Out:
# name            object
# rating          object
# genre           object
# year             int64
# released        object
# score          float64
# votes          float64
# director        object
# writer          object
# star            object
# country         object
# budget           Int64
# gross            Int64
# company         object
# runtime        float64
# yearcorrect      Int64
# dtype: object

# %%
df.drop_duplicates()
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
# scatterplot w/ linreg trend line for how much a movie grosses vs. its budget

sns.regplot(x="budget", y="gross", data=df, line_kws={"color": "blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# this can also be done with pandas's scatterplot, though you have to make your own trendline

df2 = df.dropna()

x = df2['budget']
y = df2['gross']

plt.scatter(x, y)

plt.title('Movie Budget vs Gross Earnings')

plt.xlabel('Budget (in $10m units)')

plt.ylabel('Gross Earnings (in $100m units)')

z = np.polyfit(x, y, 1)

p = np.poly1d(z)

print('R squared value = ' + str(skm.r2_score(y, p(x))))

plt.plot(x,p(x),"b")

plt.show()
# Out:
# R squared value = 0.5479649457884108

# %%
# correlation matrices, visualizing different protocols

df.corr()
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
# score    0.097995  1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.222945  0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.329321  0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.257486  0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.120811  0.399451  0.309212  0.320447  0.245216  1.000000

# %%
df.corr(method ='pearson')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
# score    0.097995  1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.222945  0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.329321  0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.257486  0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.120811  0.399451  0.309212  0.320447  0.245216  1.000000

# %%
df.corr(method ='kendall')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.067652  0.331465  0.224120  0.200618  0.097184
# score    0.067652  1.000000  0.300115 -0.000566  0.086046  0.283611
# votes    0.331465  0.300115  1.000000  0.353702  0.548899  0.198240
# budget   0.224120 -0.000566  0.353702  1.000000  0.512637  0.235483
# gross    0.200618  0.086046  0.548899  0.512637  1.000000  0.168933
# runtime  0.097184  0.283611  0.198240  0.235483  0.168933  1.000000

# %%
df.corr(method ='spearman')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.099045  0.469829  0.317336  0.293084  0.142977
# score    0.099045  1.000000  0.428138 -0.001403  0.126116  0.399857
# votes    0.469829  0.428138  1.000000  0.502466  0.742050  0.290159
# budget   0.317336 -0.001403  0.502466  1.000000  0.693670  0.336370
# gross    0.293084  0.126116  0.742050  0.693670  1.000000  0.246243
# runtime  0.142977  0.399857  0.290159  0.336370  0.246243  1.000000

# %%
correlation_matrix = df.corr()

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Numeric Features")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# some values are not numerically comparable, so use pandas' factorize function to 'numerize' them

df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000  0.143938  0.036367  0.965761  0.959015 -0.046733
# rating    0.143938  1.000000 -0.086723  0.156713  0.146606  0.012595
# genre     0.036367 -0.086723  1.000000  0.037184  0.035940 -0.002437
# year      0.965761  0.156713  0.037184  1.000000  0.993190 -0.044981
# released  0.959015  0.146606  0.035940  0.993190  1.000000 -0.045761
# score    -0.046733  0.012595 -0.002437 -0.044981 -0.045761  1.000000
# votes     0.287776  0.099972  0.023285  0.312401  0.299905 -0.009749
# director  0.745905  0.085520  0.047288  0.770497  0.770876 -0.022687
# writer    0.805211  0.103623  0.033688  0.824770  0.819617 -0.034685
# star      0.731565  0.093116  0.038649  0.756400  0.754468 -0.009896
# country   0.142828  0.000494 -0.015795  0.140216  0.148468  0.023097
# budget    0.277488  0.193353  0.073008  0.300621  0.285691 -0.012642
# gross     0.947324  0.158582  0.038616  0.980873  0.976423 -0.047041
# ...

# %%
# the new heatmap with factorized values

correlation_matrix = df.apply(lambda x: x.factorize()[0]).corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Numeric Features")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
# a similar method of doing this would look like this:

# df_numerized = df
# for col in df_numerized.columns:
#     if (df_numerized[col].dtype == 'object'):
#         df_numerized[col] = df_numerized[col].astype('category')
#         df_numerized[col] = df_numerized[col].cat.codes

# df_numerized

# %%
pd.set_option("display.max_rows", False)

# %%
# shows the pivot tables that the correlation matrix is effectively made of

corr_matrix = df.apply(lambda x: x.factorize()[0]).corr()

corr_pairs = corr_matrix.unstack()

print(corr_pairs)
# Out:
# name      name        1.000000
#           rating      0.143938
#           genre       0.036367
#           year        0.965761
#           released    0.959015
#           score      -0.046733
#           votes       0.287776
#           director    0.745905
#           writer      0.805211
#           star        0.731565
#           country     0.142828
#           budget      0.277488
#           gross       0.947324
#           company     0.591667
#           runtime     0.048955
# rating    name        0.143938
#           rating      1.000000
#           genre      -0.086723
#           year        0.156713
#           released    0.146606
#           score       0.012595
#           votes       0.099972
#           director    0.085520
#           writer      0.103623
#           star        0.093116
#           country     0.000494
#           budget      0.193353
#           gross       0.158582
#           company    -0.028035
#           runtime     0.032741
# ...

# %%
sorted_pairs = corr_pairs.sort_values(kind="quicksort")

print(sorted_pairs)
# Out:
# budget    company    -0.092249
# company   budget     -0.092249
# genre     rating     -0.086723
# rating    genre      -0.086723
# budget    country    -0.082082
# country   budget     -0.082082
# gross     score      -0.047041
# score     gross      -0.047041
#           name       -0.046733
# name      score      -0.046733
# votes     country    -0.045914
# country   votes      -0.045914
# released  score      -0.045761
# score     released   -0.045761
# year      score      -0.044981
# score     year       -0.044981
# writer    score      -0.034685
# score     writer     -0.034685
# company   score      -0.028432
# score     company    -0.028432
# company   rating     -0.028035
# rating    company    -0.028035
# director  score      -0.022687
# score     director   -0.022687
# genre     country    -0.015795
# country   genre      -0.015795
# score     budget     -0.012642
# budget    score      -0.012642
# runtime   director   -0.011070
# director  runtime    -0.011070
# ...

# %%
# Pick out those with high correlations

better_pairs_05 = sorted_pairs[abs(sorted_pairs) > 0.5]

print(better_pairs_05)
# Out:
# star      company     0.527116
# company   star        0.527116
#           writer      0.546151
# writer    company     0.546151
# director  company     0.552258
# company   director    0.552258
# gross     company     0.588156
# company   gross       0.588156
#           name        0.591667
# name      company     0.591667
# year      company     0.601571
# company   year        0.601571
# released  company     0.607954
# company   released    0.607954
# writer    star        0.675685
# star      writer      0.675685
# director  star        0.682385
# star      director    0.682385
# name      star        0.731565
# star      name        0.731565
# gross     star        0.735680
# star      gross       0.735680
# director  name        0.745905
# name      director    0.745905
# writer    director    0.748340
# director  writer      0.748340
# gross     director    0.750911
# director  gross       0.750911
# released  star        0.754468
# star      released    0.754468
# ...

# %%
# Looking at the top 15 compaies by gross revenue

CompanyGrossSum = df.groupby('company')[["gross"]].sum()
CompanyGrossSum
# Out:
#                                            gross
# company
# "DIA" Productions GmbH & Co. KG       44350926.0
# "Weathering With You" Film Partners  193457467.0
# .406 Production                          10580.0
# 1+2 Seisaku Iinkai                     1196218.0
# 10 West Studios                         814906.0
# 120 Films                              6479328.0
# 120dB Films                             395048.0
# 13 Productions                           25461.0
# 1492 Pictures                        217256250.0
# ...                                          ...
# Zucker Brothers Productions            7027290.0
# Zupnik-Curtis Enterprises             12145169.0
# double A Films                         2046433.0
# erbp                                    587174.0
# i am OTHER                            17986781.0
# i5 Films                              10031529.0
# iDeal Partners Film Fund                506303.0
# micro_scope                            7099598.0
# ...

# %%
CompanyGrossSum = df.groupby('company')[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values('gross', ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company
# Warner Bros.                 56491421806
# Universal Pictures           52514188890
# Columbia Pictures            43008941346
# Paramount Pictures           40493607415
# Twentieth Century Fox        40257053857
# Walt Disney Pictures         36327887792
# New Line Cinema              19883797684
# Marvel Studios               15065592411
# DreamWorks Animation         11873612858
# Touchstone Pictures          11795832638
# Dreamworks Pictures          11635441081
# Metro-Goldwyn-Mayer (MGM)     9230230105
# Summit Entertainment          8373718838
# Pixar Animation Studios       7886344526
# Fox 2000 Pictures             7443502667
# Name: gross, dtype: int64

# %%
CompanyGrossSum = df.groupby(['company', 'year'])[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values(['gross','company','year'], ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company                year
# Walt Disney Pictures   2019    5773131804
# Marvel Studios         2018    4018631866
# Universal Pictures     2015    3834354888
# Twentieth Century Fox  2009    3793491246
# Walt Disney Pictures   2017    3789382071
# Paramount Pictures     2011    3565705182
# Warner Bros.           2010    3300479986
#                        2011    3223799224
# Walt Disney Pictures   2010    3104474158
# Paramount Pictures     2014    3071298586
# Columbia Pictures      2006    2934631933
#                        2019    2932757449
# Marvel Studios         2019    2797501328
# Warner Bros.           2018    2774168962
# Columbia Pictures      2011    2738363306
# Name: gross, dtype: int64

# %%
# swarm plot takes far too long, stripplot is necessary

sns.stripplot(x="rating", y="gross", data=df)
# Out:
# <AxesSubplot:xlabel='rating', ylabel='gross'>
